# %%
# Script por Madeleine Santiago 10.05.2021
# Anaconda Notebook para el preprocesamiento
# del Proyecto Parte 1. del Modulo 6. Análisis Multivariado del
# Dip en Estadistica Aplicada ITAM 2020-2021
# ----------

import pandas as pd
file='DataPanelWHR2021C2.xls'
df=pd.read_excel(file)
df=df[df['year']==2019].dropna(axis=0)
df.head()
# Out:
#    Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 11  Afghanistan  2019     2.375092            7.697248        0.419973
# 23      Albania  2019     4.995318            9.544080        0.686365
# 32      Algeria  2019     4.744627            9.336946        0.803259
# 50    Argentina  2019     6.085561           10.000340        0.896371
# 65      Armenia  2019     5.488087            9.521770        0.781604
#
#     Healthy life expectancy at birth  Freedom to make life choices  \
# 11                         52.400002                      0.393656
# 23                         69.000000                      0.777351
# 32                         66.099998                      0.385083
# 50                         69.000000                      0.817053
# 65                         67.199997                      0.844324
#
#     Generosity  Perceptions of corruption  Positive affect  Negative affect
# ...

# %%
file2='DataForFigure2.1WHR2021C2.xls'
df2=pd.read_excel(file2)
df2 = df2[['Country name','Regional indicator']]
df2.head()
# Out:
#   Country name Regional indicator
# 0      Finland     Western Europe
# 1      Denmark     Western Europe
# 2  Switzerland     Western Europe
# 3      Iceland     Western Europe
# 4  Netherlands     Western Europe

# %%
df=pd.merge(df, df2,on='Country name')
df=df.drop(['year'], axis=1)
#print(df.head())
df.describe()
# Out:
#        Life Ladder  Log GDP per capita  Social support  \
# count   126.000000          126.000000      126.000000
# mean      5.559387            9.421646        0.811181
# std       1.130363            1.147823        0.122358
# min       2.375092            6.965763        0.419973
# 25%       4.918828            8.547881        0.746700
# 50%       5.639185            9.559665        0.842202
# 75%       6.266353           10.383684        0.912877
# max       7.780348           11.648169        0.964489
#
#        Healthy life expectancy at birth  Freedom to make life choices  \
# count                        126.000000                    126.000000
# mean                          64.891625                      0.793967
# std                            6.874025                      0.117725
# min                           48.700001                      0.385083
# 25%                           59.349999                      0.716678
# ...

# %%
import matplotlib.pyplot as plt
corr=df.corr()
#plt.matshow(df.corr())
#plt.show()

corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
# #T_dc6b479c_b202_11eb_9db0_acbc32bf41b1row0_col0,#T_dc6b479c_b202_11eb_9db0_acbc32bf41b1row1_col1,#T_dc6b479c_b202_11eb_9db0_acbc32bf41b1row2_col2,#T_dc6b479c_b202_11eb_9db0_acbc32bf41b1row3_col3,#T_dc6b479c_b202_11eb_9db0_acbc32bf41b1row4_col4,#T_dc6b479c_b202_11eb_9db0_acbc32bf41b1row5_col5,#T_dc6b479c_b202_11eb_9db0_acbc32bf41b1row6_col6,#T_dc6b479c_b202_11eb_9db0_acbc32bf41b1row7_col7,#T_dc6b479c_b202_11eb_9db0_acbc32bf41b1row8_col8{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_dc6b479c_b202_11eb_9db0_acbc32bf41b1row0_col1,#T_dc6b479c_b202_11eb_9db0_acbc32bf41b1row0_col3,#T_dc6b479c_b202_11eb_9db0_acbc32bf41b1row3_col0{
#             background-color:  #e36c55;
#             color:  #000000;
#         }#T_dc6b479c_b202_11eb_9db0_acbc32bf41b1row0_col2{
#             background-color:  #e36b54;
#             color:  #000000;
#         }#T_dc6b479c_b202_11eb_9db0_acbc32bf41b1row0_col4{
# ...

# %%
df.sort_values(by=['Life Ladder'],ascending=False)
# Out:
#     Country name  Life Ladder  Log GDP per capita  Social support  \
# 35       Finland     7.780348           10.791813        0.937416
# 111  Switzerland     7.694221           11.136454        0.948513
# 29       Denmark     7.693003           10.954033        0.957706
# 88        Norway     7.442140           11.060889        0.941784
# 82   Netherlands     7.425269           10.953283        0.941477
# ..           ...          ...                 ...             ...
# 124       Zambia     3.306797            8.154642        0.637894
# 98        Rwanda     3.268152            7.708061        0.489458
# 47         India     3.248770            8.817933        0.560781
# 125     Zimbabwe     2.693523            7.950132        0.759162
# 0    Afghanistan     2.375092            7.697248        0.419973
#
#      Healthy life expectancy at birth  Freedom to make life choices  \
# 35                          72.000000                      0.947617
# ...

# %%
df=df.drop(['Life Ladder'], axis=1)
corr=df.corr()

corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
# #T_dc726810_b202_11eb_9db0_acbc32bf41b1row0_col0,#T_dc726810_b202_11eb_9db0_acbc32bf41b1row1_col1,#T_dc726810_b202_11eb_9db0_acbc32bf41b1row2_col2,#T_dc726810_b202_11eb_9db0_acbc32bf41b1row3_col3,#T_dc726810_b202_11eb_9db0_acbc32bf41b1row4_col4,#T_dc726810_b202_11eb_9db0_acbc32bf41b1row5_col5,#T_dc726810_b202_11eb_9db0_acbc32bf41b1row6_col6,#T_dc726810_b202_11eb_9db0_acbc32bf41b1row7_col7{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_dc726810_b202_11eb_9db0_acbc32bf41b1row0_col1{
#             background-color:  #df634e;
#             color:  #000000;
#         }#T_dc726810_b202_11eb_9db0_acbc32bf41b1row0_col2{
#             background-color:  #d44e41;
#             color:  #000000;
#         }#T_dc726810_b202_11eb_9db0_acbc32bf41b1row0_col3{
#             background-color:  #efcfbf;
#             color:  #000000;
#         }#T_dc726810_b202_11eb_9db0_acbc32bf41b1row0_col4{
# ...

# %%
df.to_csv('Happiness_Index.csv')
print('Done')
# Out:
# Done

# %%
for i in df['Regional indicator'].unique():
    print('********')
    print(i)
    for j in df[df['Regional indicator']==i]['Country name']:
        print('  ',j)
# Out:
# ********
# South Asia
#    Afghanistan
#    Bangladesh
#    India
#    Nepal
#    Pakistan
#    Sri Lanka
# ********
# Central and Eastern Europe
#    Albania
#    Bosnia and Herzegovina
#    Bulgaria
#    Croatia
#    Estonia
#    Hungary
#    Latvia
#    Lithuania
#    Montenegro
#    North Macedonia
#    Poland
#    Romania
#    Serbia
#    Slovakia
#    Slovenia
# ********
# Middle East and North Africa
#    Algeria
#    Israel
#    Lebanon
#    Libya
#    Morocco
#    Tunisia
#    Turkey
# ********
# Latin America and Caribbean
#    Argentina
#    Bolivia
#    Brazil
#    Chile
#    Colombia
#    Costa Rica
#    Dominican Republic
#    Ecuador
#    El Salvador
#    Guatemala
#    Honduras
#    Jamaica
#    Mexico
#    Nicaragua
#    Panama
#    Paraguay
#    Peru
#    Uruguay
# ********
# Commonwealth of Independent States
#    Armenia
#    Azerbaijan
#    Belarus
#    Georgia
#    Kazakhstan
#    Kyrgyzstan
#    Moldova
#    Russia
#    Ukraine
#    Uzbekistan
# ********
# ...
